# %%
import yfinance as yf
import pandas as pd

# Define the correct ticker symbol for Eternal Limited on NSE
ticker = "TRENT.NS"

# Download historical OHLC data (e.g., last 1 month, daily intervals)
data = yf.download(ticker, period="2mo", interval="1d")

# Optional: reset index for cleaner DataFrame
df = data.reset_index()

print(df.head())
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_21332\3176343752.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="2mo", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price        Date    Close     High      Low     Open    Volume
# Ticker            TRENT.NS TRENT.NS TRENT.NS TRENT.NS  TRENT.NS
# 0      2025-06-16   5679.5   5695.0   5561.5   5589.0    605268
# 1      2025-06-17   5626.5   5702.0   5602.0   5687.0    529572
# 2      2025-06-18   5735.0   5759.0   5627.0   5654.0    864129
# 3      2025-06-19   5723.5   5800.0   5665.0   5800.0    886990
# 4      2025-06-20   5897.5   6030.0   5720.0   5756.0  10424185

# %%
df
# Out:
# Price        Date    Close     High      Low     Open    Volume
# Ticker            TRENT.NS TRENT.NS TRENT.NS TRENT.NS  TRENT.NS
# 0      2025-06-16   5679.5   5695.0   5561.5   5589.0    605268
# 1      2025-06-17   5626.5   5702.0   5602.0   5687.0    529572
# 2      2025-06-18   5735.0   5759.0   5627.0   5654.0    864129
# 3      2025-06-19   5723.5   5800.0   5665.0   5800.0    886990
# 4      2025-06-20   5897.5   6030.0   5720.0   5756.0  10424185
# 5      2025-06-23   6120.0   6210.0   5830.0   5850.0   2271641
# 6      2025-06-24   6057.5   6205.0   6033.0   6174.0   1459591
# 7      2025-06-25   6124.5   6156.0   6080.0   6090.0    815696
# 8      2025-06-26   6107.0   6135.0   6013.0   6123.0    851467
# 9      2025-06-27   6019.5   6159.0   5982.0   6119.0   1935325
# 10     2025-06-30   6217.5   6261.0   5968.0   6050.0   2136461
# 11     2025-07-01   6144.0   6226.5   6130.0   6226.5    558024
# 12     2025-07-02   6222.5   6252.0   6063.0   6130.5   1159148
# ...
